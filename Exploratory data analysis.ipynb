# %%
'''Exploratory Data Analysis on a Dataset'''
#importing data file
import pandas as pd
df=pd.read_csv("Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#Handling missing values
#STEP-1:Identifying the Missing values
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
#Imputation of the misssing values using mean.
df.fillna(df.mean(), inplace=True)
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#Handling outliers using z-score calculations 
# Calculate the z-score for each column
z_scores = (df - df.mean()) / df.std()

# Define the threshold for outliers
threshold = 3

# Select rows where the absolute z-score is less than the threshold
df = df[(abs(z_scores) < threshold).all(axis=1)]

# Print the cleaned DataFrame
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2120  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#2.Statistical Summary:
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  1869.000000  1869.000000  1869.000000  1869.000000  1869.000000
# mean    133.306955     0.003194     0.004240     0.004391     0.001732
# std       9.899631     0.003767     0.013554     0.002904     0.002705
# min     106.000000    -0.000185    -0.005106    -0.000132    -0.000124
# 25%     126.000000     0.000000     0.000000     0.002002     0.000000
# 50%     133.000000     0.001733     0.000000     0.004556     0.000000
# 75%     141.000000     0.005650     0.002358     0.006579     0.003036
# max     160.000000     0.016000     0.189320     0.013861     0.011837
#
#                  DS           DP         ASTV         MSTV         ALTV  \
# count  1.869000e+03  1869.000000  1869.000000  1869.000000  1869.000000
# mean   3.736781e-08     0.000102    46.870868     1.283173     9.193894
# std    6.367633e-07     0.000404    16.834525     0.778099    16.574763
# ...

# %%
#3.Data Visualization:
#creating histogram for all numerical columns to understand the distribution of data.
import matplotlib.pyplot as plt

# Create histograms for each numerical column
for col in df.select_dtypes(include=['number']):
    plt.hist(df[col], bins=10)
    plt.title(f"Histogram of {col}")
    plt.show()

# %%
# Separating the numerical and the categorical columns.
numerical_cols = df.select_dtypes(include=["number"])
categorical_cols = df.select_dtypes(exclude=["number"])

# Generating scatter plots to understand the pairs of numerical variables.
import matplotlib.pyplot as plt
for i, col1 in enumerate(numerical_cols):
    for j, col2 in enumerate(numerical_cols):
        if i > j:
            plt.scatter(df[col1], df[col2])
            plt.xlabel(col1)
            plt.ylabel(col2)
            plt.show()

# %%
'''insights of data visualizations 
from the above box plot and scatterplots fetal movements (FM), uterine contractions (UC), various decelerations (DL, DS, DP), short-term variability (ASTV, MSTV),
long-term variability (ALTV, MLTV), baseline FHR (LB), and accelerations (AC)), here are some inferences that i decide:

Fetal Movements(FM) and Accelerations(AC):The distribution of FM and AC can help establish a baseline for normal activity patterns.
A healthy pregnancy might show a correlation between increased fetal movement and accelerations in FHR.

Uterine Contractions(UC) and Decelerations(DL, DP): The UC histogram can inform about typical contraction frequency during labor.
There might be a positive correlation between contractions and late or prolonged decelerations (DL, DP). 
However, the severity and duration of these dips in FHR are crucial for assessing potential fetal stress.

Abnormal Short-Term Variability(ASTV) and Baseline FHR(LB): The distribution of ASTV and LB can help identify potential abnormalities. 
Reduced short-term variability (ASTV) and a lower baseline FHR (LB) can be signs of fetal stress, 
and their combined presence might warrant closer monitoring.

Long-Term Variability(MLTV) and Overall FHR Pattern:A healthy long-term variability(MLTV) distribution alongside a normal baseline FHR (LB) and
frequent accelerations (AC) suggests a reassuring overall FHR pattern, potentially indicating a responsive fetus.

All Histograms:The distributions across all these histograms can help establish a reference range for normal FHR characteristics 
during pregnancy and delivery. Deviations from these ranges, like reduced variability or frequent decelerations, might require further investigation.

By analyzing the distributions in these histograms,boxplot healthcare professionals can gain valuable insights into fetal well-being and potential risks.

# %%
'''summary of assignment:
from the overall observations I come to know that the fetal health is measuring by FHR characteristics.
,Out of the various ways and problems, The main observations and outcomes are:

Understanding FHR Patterns:
The histograms display the distribution of many FHR indicators, such as accelerations (AC), contractions (UC), fetal movements (FM), 
different types of decelerations (DL, DS, DP), short-term variability (ASTV, MSTV), long-term variability (ALTV, MLTV), and baseline FHR (LB).
graphs showing the dispersal of values in each histogram make it possible to create a standard model for typical FHR patterns in pregnancy
and delivery. They will help to identify any deviations from the fitter range, which in turn, will require further scrutiny.

Identifying Potential Risks:
Deceleration histograms (DL, DS, DP), abnormal variability (ASTV) and low baseline FHR (LB) are signals of serious states of fetal stress
or distress that are at risk of sudden onset. Doctors would call the deliveries with these problems the high-risk ones if they occurred more 
frequently or more heavily.Doctors can use visual aids like these for triage of deliveries whose FHR characteristics fall out of the expected boundaries.

Boundaries and Specialization:
It is necessary to remind ourselves that these histograms show only one data point and boxplot shows only correlation between data points do not cover the 
whole picture of fetal well-being.Analysing FHR data is a difficult task and is better off left to someone with expertise who can take into 
account other things such as gestational age, woman's medical status, and the extra FHR metrics.

Decision-Making and Future Outcomes:
Not only can healthcare professionals,people who track the newborn's heartbeat in real-time and interpret the data obtained when tracing
the fluctuating patterns of normal and abnormal fetal heart rate (FHR). This information can be further used to determine the necessity
of immediate interventions during delivery and the possibility of threats that may affect the blood exchange of the fetus from its mother.
The fundamental problem of future forecasting using histograms and scatterplots would be based on their sole function which is this that is used alone.
Because of this, we need to foster to check them with all other data to confirm our intuition and to follow that up with effective diagnosis 
when necessary. Physicians can use it for a general infertility diagnosis, as well as screening for trisomies and congenital neck problems
in the fetus.

# %%
'''conclusion:
 In this exploratory analysis of the cardiographic dataset, 
 we have uncovered several insights and patterns that provide a deeper understanding of the dataset's underlying structure. 
Through statistical summaries, visualizations, and data manipulation techniques, we have identified correlations, trends,
and clusters that reveals the information on the relationships between variables.
Our analysis revealed correlation  increased fetal movement and accelerations in FHR and might be a positive correlation between 
contractions and late or prolonged decelerations (DL, DP).
These FHR histograms are the first step for obstetricians to find out about the situation of the unborn infant,
they help the doctor in determining the level of conduction of various attributes of FHR during birth.
This means the ECG is not the only one that we should turn to for safe reproduction.
